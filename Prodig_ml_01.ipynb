# %%
# Exploratory Data Analysis (EDA) on House Prices Dataset

##  Introduction
#This notebook presents an exploratory data analysis (EDA) on the House Prices dataset from Kaggle. The objective is to understand the structure of the dataset, identify key features influencing house prices and uncover patterns or anomalies that may help in predictive modeling.

# %% [markdown]
# Import Libraries and Load Data

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# Load the dataset directly from the D2L source
url = "https://d2l-data.s3-accelerate.amazonaws.com/kaggle_house_pred_train.csv"
df = pd.read_csv(url)

# Display shape and preview
print("Dataset Shape:", df.shape)
df.head()
# Out:
# Dataset Shape: (1460, 81)
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities  ... PoolArea PoolQC Fence MiscFeature MiscVal MoSold  \
# 0         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 1         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      5
# 2         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      9
# 3         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 4         Lvl    AllPub  ...        0    NaN   NaN         NaN       0     12
#
# ...

# %% [markdown]
#  Basic Information

# %%
# Check data types and non-null counts
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 81 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             1460 non-null   int64
#  1   MSSubClass     1460 non-null   int64
#  2   MSZoning       1460 non-null   object
#  3   LotFrontage    1201 non-null   float64
#  4   LotArea        1460 non-null   int64
#  5   Street         1460 non-null   object
#  6   Alley          91 non-null     object
#  7   LotShape       1460 non-null   object
#  8   LandContour    1460 non-null   object
#  9   Utilities      1460 non-null   object
#  10  LotConfig      1460 non-null   object
#  11  LandSlope      1460 non-null   object
#  12  Neighborhood   1460 non-null   object
#  13  Condition1     1460 non-null   object
#  14  Condition2     1460 non-null   object
#  15  BldgType       1460 non-null   object
#  16  HouseStyle     1460 non-null   object
# ...

# %%
# Describe numerical columns
train_df.describe()
# Out:
#                 Id   MSSubClass  LotFrontage        LotArea  OverallQual  \
# count  1460.000000  1460.000000  1201.000000    1460.000000  1460.000000
# mean    730.500000    56.897260    70.049958   10516.828082     6.099315
# std     421.610009    42.300571    24.284752    9981.264932     1.382997
# min       1.000000    20.000000    21.000000    1300.000000     1.000000
# 25%     365.750000    20.000000    59.000000    7553.500000     5.000000
# 50%     730.500000    50.000000    69.000000    9478.500000     6.000000
# 75%    1095.250000    70.000000    80.000000   11601.500000     7.000000
# max    1460.000000   190.000000   313.000000  215245.000000    10.000000
#
#        OverallCond    YearBuilt  YearRemodAdd   MasVnrArea   BsmtFinSF1  ...  \
# count  1460.000000  1460.000000   1460.000000  1452.000000  1460.000000  ...
# mean      5.575342  1971.267808   1984.865753   103.685262   443.639726  ...
# std       1.112799    30.202904     20.645407   181.066207   456.098091  ...
# ...

# %% [markdown]
#  Summary Statistics

# %%
# Summary statistics for numerical columns
df.describe()
# Out:
#                 Id   MSSubClass  LotFrontage        LotArea  OverallQual  \
# count  1460.000000  1460.000000  1201.000000    1460.000000  1460.000000
# mean    730.500000    56.897260    70.049958   10516.828082     6.099315
# std     421.610009    42.300571    24.284752    9981.264932     1.382997
# min       1.000000    20.000000    21.000000    1300.000000     1.000000
# 25%     365.750000    20.000000    59.000000    7553.500000     5.000000
# 50%     730.500000    50.000000    69.000000    9478.500000     6.000000
# 75%    1095.250000    70.000000    80.000000   11601.500000     7.000000
# max    1460.000000   190.000000   313.000000  215245.000000    10.000000
#
#        OverallCond    YearBuilt  YearRemodAdd   MasVnrArea   BsmtFinSF1  ...  \
# count  1460.000000  1460.000000   1460.000000  1452.000000  1460.000000  ...
# mean      5.575342  1971.267808   1984.865753   103.685262   443.639726  ...
# std       1.112799    30.202904     20.645407   181.066207   456.098091  ...
# ...

# %% [markdown]
#  Check Missing Value

# %%
# Total missing values in each column
missing_values = df.isnull().sum()
missing_values[missing_values > 0].sort_values(ascending=False)
# Out:
# PoolQC          1453
# MiscFeature     1406
# Alley           1369
# Fence           1179
# MasVnrType       872
# FireplaceQu      690
# LotFrontage      259
# GarageType        81
# GarageYrBlt       81
# GarageFinish      81
# GarageQual        81
# GarageCond        81
# BsmtFinType2      38
# BsmtExposure      38
# BsmtFinType1      37
# BsmtCond          37
# BsmtQual          37
# MasVnrArea         8
# Electrical         1
# dtype: int64

# %% [markdown]
# Correlation Matrix with SalePrice

# %%
# Compute correlations with SalePrice
correlation = df.corr(numeric_only=True)['SalePrice'].sort_values(ascending=False)

# Display top 10 positively correlated features
print("Top 10 correlated features with SalePrice:")
correlation.head(11)  # Including SalePrice itself
# Out:
# Top 10 correlated features with SalePrice:
# SalePrice       1.000000
# OverallQual     0.790982
# GrLivArea       0.708624
# GarageCars      0.640409
# GarageArea      0.623431
# TotalBsmtSF     0.613581
# 1stFlrSF        0.605852
# FullBath        0.560664
# TotRmsAbvGrd    0.533723
# YearBuilt       0.522897
# YearRemodAdd    0.507101
# Name: SalePrice, dtype: float64

# %% [markdown]
# Visualizing Correlation Heatmap

# %%
# Select top 10 most correlated features with SalePrice
top_corr_features = correlation.index[1:11]
plt.figure(figsize=(10, 8))
sns.heatmap(df[top_corr_features].corr(), annot=True, cmap='coolwarm')
plt.title("Correlation Heatmap of Top Features")
plt.show()

# %% [markdown]
# Distribution of SalePrice

# %%
sns.histplot(df['SalePrice'], kde=True, color='skyblue')
plt.title("Distribution of SalePrice")
plt.show()

# %% [markdown]
# Pairplot of Key Variables

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Select top 5 features for clarity
selected_features = ['SalePrice', 'OverallQual', 'GrLivArea', 'GarageCars', 'TotalBsmtSF']

# Create the pairplot
sns.pairplot(train_df[selected_features], diag_kind='kde', corner=True)

# Render the plot properly
plt.show()

# %% [markdown]
# Boxplots for Categorical Features vs SalePrice

# %%
plt.figure(figsize=(10, 6))
sns.boxplot(x='OverallQual', y='SalePrice', data=df)
plt.title("SalePrice vs Overall Quality")
plt.show()

# %% [markdown]
# Outlier Detection

# %%
# Visual inspection for outliers in GrLivArea
plt.scatter(df['GrLivArea'], df['SalePrice'], alpha=0.5)
plt.title('GrLivArea vs SalePrice')
plt.xlabel('GrLivArea')
plt.ylabel('SalePrice')
plt.show()

# %% [markdown]
# Summary & Key Insights

# %% [raw]
# #Summary Report: Task 1 – EDA
#
# ##Key Findings:
# 1. **Overall Quality** has the strongest positive correlation with SalePrice (0.79).
# 2. **GrLivArea** and **GarageCars** also strongly influence SalePrice.
# 3. **TotalBsmtSF** and **1stFlrSF** are moderately correlated with SalePrice.
# 4. **Neighborhood** and **YearBuilt** are also important categorical indicators.
# 5. There are **missing values** in many columns, notably in **PoolQC**, **MiscFeature**, **Alley**, etc.
# 6. SalePrice is **right-skewed**, suggesting a possible log transformation in future modeling.
# 7. There are a few **outliers** in variables like GrLivArea which may affect regression accuracy.
#
# ## Conclusion:
# This EDA lays the groundwork for predictive modeling. It reveals that a few core numerical and categorical features have strong influence on house prices. Addressing missing data and outliers will be crucial in the next steps.
#
# ---
